# %% [markdown]
# # Overview
# We discuss the contents of the *evol_dist.ipynb* file, which uses the scattering matrix (discussed in dmbinaries/evolution) to set limits on subhalo populations. In that section, we calculated the separation distribution using
# $$
# \begin{aligned}
#     \phi(s) = \int da \ S(s|a) \ \phi_0(a).
# \end{aligned}
# $$
# This solves the problem of characterizing the separation distribution of true binaries. However, to properly model the dataset, we must account for *Gaia* selection effects and contamination.
#
# We assume $\phi_{0}(a;\lambda) \propto a^{-\lambda}$. As discussed in Sec. IV of the paper, we must account for selection effects. By accounting for this, we can obtain the probability of detecting and selecting a binary:
# $$
# \begin{align}
#     p_b(s | d, \Delta G ; \lambda, f_{p}, \vec{\zeta}) = \frac{\phi(s |\lambda, f_{p}, \vec{\zeta}) \ \Theta(s/d - \theta_{\Delta G})}{\int ds' \ \phi(s'|\lambda, f_{p}, \vec{\zeta})  \ \Theta(s'/d - \theta_{\Delta G})},
# \end{align}
# $$
# Second, we account for chance alignments by assuming they obey a power law in separation and marginalizing our constraints over them. By subjecting them to the same selection effects, the probability of detecting and selecting a chance alignment is given by:
# $$
# \begin{align}
#     p_{c}(s | d, \Delta G ; \lambda_{c}) = \frac{\phi_{c}(s | \lambda_{c}) \ \Theta(s/d - \theta_{\Delta G})}{\int ds'  \ \phi_{c}(s'| \lambda_{c})  \ \Theta(s'/d - \theta_{\Delta G})}.
# \end{align}
# $$
# Putting these together by using the contamination probability $\mathcal{R}$, the probability of detecting and selecting either a binary or chance-alignment is
# $$
# \begin{align} \label{eq:probability_final}
#      p(s|d,& \Delta G, \mathcal{R}; \lambda, \lambda_{c}, f_{p}, \vec{\zeta}) = (1 - \mathcal{R}) \ p_b(s | d, \Delta G ;  \lambda, f_{p}, \vec{\zeta}) +  \mathcal{R} \ p_{c}(s | d, \Delta G ; \lambda_{c}),
# \end{align}
# $$
# From this, we can define the likelihood function:
# $$
# \begin{equation}
#     {\cal L} = \prod_{i} p(s_{i} | d_{i}, \Delta G_{i}, \mathcal{R}_{i}; \lambda, \lambda_{c}, f_{p}, \vec{\zeta}),
# \end{equation}
# $$
# from which we can use Bayes' Theorem to infer a posterior distribution for the model parameters.
#
# Thus, we apply the scattering matrix formalism and our statistical methods here.

# %% [markdown]
# # Initialization
# ## Load Parameters
# We load the parameters defined in the *evolution.ipynb* code to specify the scattering matrix that we wish to load. This effectively specifies the type of perturbers that interact with the binaries.

# %%
# load packages and functions
## plotting packages

import sys, os, time, fileinput
import numpy as np
import math as math 

from scipy.stats import maxwell, rv_histogram
from scipy.integrate import quad, dblquad
from scipy.special import erf
from scipy.interpolate import interp1d
from scipy.optimize import minimize

import emcee # NOTE: Version 2.2.1 (will need to downgrade to this version for the code to work)
import pandas as pd
import matplotlib.pyplot as plt

# %%
# input parameters

## perturber mass (M_sol)
log_m = float(3)
str_log_m = str.format('{0:.3f}',log_m)
m = 10**float(str_log_m)

## scale radius 
log_rs = float(-1) # NFW scale radius (pc)
str_log_rs = str.format('{0:.3f}',log_rs)

## concentration
alpha = float(0) # NFW concentration
str_alpha = str.format('{0:.3f}',alpha)

## halo fraction
log_f = float(0.2) # halo fraction [setting max number of time steps]
f = 10**log_f
str_log_f = str.format('{0:.3f}',log_f)

# threshold fractional energy injection defining p_max
log_eps = float(-2)  
energy_fraction = 10**log_eps
str_log_eps = str.format('{0:.2f}',log_eps)

# ------------------------
## approximate number of encounters
log_K = float(4)    # log number of samples
str_log_K = str.format('{0:.2f}',log_K)
K = int(10**log_K)
# ------------------------
## list of a0-values
bin_scale = 'log'

log_alow = float(-5)
str_log_alow = str.format('{0:.3f}',log_alow)
log_ahigh = float(2)
str_log_ahigh = str.format('{0:.3f}',log_ahigh)
step_size = float(0.04) # number of bins
str_step_size = str(step_size)
#str_step_size = str.format('{0:.3f}',step_size)

log_alow_offset = float(0)
str_log_alow_offset = str.format('{0:.3f}',log_alow_offset)
log_ahigh_offset = float(0)
str_log_ahigh_offset = str.format('{0:.3f}',log_ahigh_offset)

# %%
## Conversion Factors:
kg_g = 1E-3
Msolar_kg = 5.02785E-31 # Msolar/kg
pc_m = 3.24078E-17 # pc/m
Gyr_yr = pow(10,-9) # Gyr/yr
yr_s = 3.17098E-8 # yr/s
km_m = 1/1000 # km/m
kg_GeV = 1.78266E-27 # [kg/(GeV/c**2)]
m_cm = pow(10,-2) # m/cm
pc_AU = 4.84814e-6 # pc/AU
AU_pc = 206265  # AU/pc

#-------------------------
## fixed parameters 
#m1 = 0.5 # mass of primary (M_sol)
#m2 = 0.5 # mass of secondary (M_sol)
v0 = 200 # circular velocity (km/s) 
vesc = 533 # local escape velocity (km/s)
T = 10 # evolution time (Gyr)
#rho = 0.009 # Local DM Density (M_sol / pc**3) [Yoo]
rho_pdg = 0.39 # Local DM Density (GeV / cm3)
rho = 0.39 * (Msolar_kg) * (kg_GeV) * (pc_m)**(-3) * (m_cm)**(-3) #[Ed]


## constants
G = 4.30091e-3   # Grav Constant ([pc (M_solar)^-1 (km/s)**2])

# %%
## set up maximum impact parameter and time steps

### Compute the average inverse velocity for the truncated velocity profile

def v_theta_(cos_theta,v,vesc):
    return -v*cos_theta + np.sqrt(v*v*cos_theta*cos_theta + (vesc*vesc - v*v))

def fv_no_vesc_(v, sigma):
    return v*v*np.exp(-v*v / 4 / sigma / sigma)

def dfv_dcos_theta_eff_(v_theta,sigma):
    return (1/4) * (-2 * v_theta * np.exp( - v_theta * v_theta / sigma / sigma ) 
                 + np.sqrt(np.pi) * sigma * erf(v_theta / sigma) ) 

def inv_v_avg_(sigma,vesc,normalization):
    v_avg_eff = ( dblquad(lambda cos_theta, v: 
                                     fv_no_vesc_(v, sigma) * dfv_dcos_theta_eff_(v_theta_(cos_theta,v/2,vesc),sigma) / v, 0, 2*vesc, 
                                     lambda v: 0, lambda v: 1)[0] )
    return v_avg_eff / normalization

sigma = v0/math.sqrt(2)
normalization = ( dblquad(lambda cos_theta, v: 
                                     fv_no_vesc_(v, sigma) * dfv_dcos_theta_eff_(v_theta_(cos_theta,v/2,vesc),sigma), 0, 2*vesc, 
                                     lambda v: 0, lambda v: 1)[0] )
inv_v_avg = inv_v_avg_(sigma,vesc,normalization)

### max impact parameter when the fractional energy injection falls below energy_fraction
def p_max_(a,m,M,inv_v_avg,f,energy_fraction): 
    bar_C = 2*G*m * 2*G*m / 2 * inv_v_avg
    E = G * M / 2 / a
    inv_factor = np.pi * (f * rho * T / m) * bar_C / E
    bar_delta_Eps_val = inv_factor**(-1) * energy_fraction
    #if m >= 10:
    #    return a * np.sqrt(1 + 2 * bar_delta_Eps_val**(-1) * (1 + np.sqrt(1 + bar_delta_Eps_val))) # pc
    #else:
    #    return (m/10)**(1/2) * a * np.sqrt(1 + 2 * bar_delta_Eps_val**(-1) * (1 + np.sqrt(1 + bar_delta_Eps_val))) # pc
    return a * np.sqrt(1 + 2 * bar_delta_Eps_val**(-1) * (1 + np.sqrt(1 + bar_delta_Eps_val))) # pc

### load number of time steps needed to evolve for the specified evolution time
def delta_t_(m,inv_v_avg,f,R):    # length of time step in Gyr
    delta_t_val = m / (f * rho * np.pi * R**2) * inv_v_avg
    delta_t_val_Gyr = delta_t_val * ( (km_m) / (pc_m) ) * ( (Gyr_yr) * (yr_s) ) 
    return delta_t_val_Gyr  # Gyr

p_max = p_max_(1,m,1,inv_v_avg,1,energy_fraction) # p_max value   # p_max value 
delta_t = delta_t_(m,inv_v_avg,f,p_max)    # delta_t value
N = int(T / delta_t)    # number of time steps

# ------------------------------------------------------

# load samples
## parameters
N_enc = int(K*N) # number of samples
R = p_max   # maximum impact parameter (pc)

# %% [markdown]
# ## Loading the Data File
# Here we load the data file: **catalog_data_1.0_1.0_cut_err.npy** (see **dmbinaries/data/catalog_data_analysis_edr3.ipynb** for more details)

# %%
from numpy.random import binomial

# ----------------------------------------
## Load energy injection rate data
sorted_dir = 'sorted_data/' +str_log_m+'_'+str_log_rs+'_'+str_alpha+'_'+str_log_f+'_'+str_log_eps+'_'+str_log_K
file_name = 'hists_'+str_log_m+'_'+str_log_rs+'_'+str_alpha+'_'+str_log_f+'_'+str_log_eps+'_'+str_log_K+'_'+bin_scale+'_'+str_log_alow+'_'+str_log_ahigh+'_'+str_step_size+'_'+str_log_alow_offset+'_'+str_log_ahigh_offset
## Load energy injection rate data (DR2 for higher number of simulated binaries)
#sorted_dir = 'sorted_data/' +str_log_m+'_'+str_log_rs+'_'+str_alpha+'_'+str_log_f+'_'+str_log_eps+'_'+str_log_K
#file_name = 'hists_'+str_log_m+'_'+str_log_rs+'_'+str_alpha+'_'+str_log_f+'_'+str_log_eps+'_'+str_log_K+'_'+bin_scale+'_'+str_log_alow+'_'+str_log_ahigh+'_'+str_step_size+'_'+str_log_alow_offset+'_'+str_log_ahigh_offset


results_list = np.load(os.path.join(sorted_dir, file_name + '.npy'), allow_pickle = True)

# ----------------------------------------
## Load a-values and bins

# make the array of semimajor axis values
if bin_scale=='log': 
    bins = np.arange(log_alow+log_alow_offset,log_ahigh+log_ahigh_offset+step_size,step_size)  # bins
    bins = 10**bins
    mid = 0.5 * (bins[1:] + bins[:-1])

if bin_scale=='lin':
    alow=10**(log_alow + log_alow_offset)
    ahigh=10**(log_ahigh + log_ahigh_offset)

    Nbins = 180
    bins = np.arange(alow,ahigh,Nbins)  # bins
    mid = 0.5 * (bins[1:] + bins[:-1])

# ----------------------------------------
## Load catalog (updated for loading eDR3 halo subsample)

catalog_name = 'catalog_data' + '_' + '1.0' + '_' + '1.0' + '_cut_err' + '.npy'
catalog_sep_vec, catalog_dist_vec, catalog_delta_G_vec, catalog_R_chance_align_vec = np.load(catalog_name, allow_pickle = True)

# ----------------------------------------
# This block was added in the contamination version: 
# Contamination probability extrapolated to > 1 past the s > 1 pc.
# This requires us to modify the selection fct matrix AND the log-likelihood function
s_min = np.min(catalog_sep_vec)
s_max = np.max(catalog_sep_vec)
n_min = np.where(bins <= s_min)[0][-1]
n_max = np.where(bins >= s_max)[0][0]

bins_data = bins[n_min:n_max+1]
mid_data = 0.5 * (bins_data[1:] + bins_data[:-1])

# %%
fig = plt.figure(figsize=(4, 4), dpi= 120)
ax = fig.add_subplot(111)

counts_test, bins_test, _ = ax.hist(catalog_sep_vec, bins = np.logspace(-4,0,100))
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('s (pc)')
ax.set_ylabel('Number of Binaries')
# Out:
# Text(0, 0.5, 'Number of Binaries')

# %% [markdown]
# # Constructing the Log-Likelihood
# ## Evolving Separation Distributions with Arbitrary Initial Semimajor Axis Distributions
# Recall, the evolved distribution can be obtained from the scattering matrix by computing
# $$
# \begin{aligned}
#     \phi(s) = \int da \ S(s|a) \ \phi_0(a),
# \end{aligned}
# $$
# We approximate this integral using the approximate scattering matrix $S(s_{i}|a_{j})$ and approximating the integral to a sum. I.e.,
# $$ \begin{aligned}
#     \phi(s_{i}) & \sim  \sum_{j} \ \Delta a_{j} \ S(s_{i}|a_{j}) \ \phi_{0}(a_{j}) \\
#     & = \sum_{j} \left [ \Delta \vec{a} \odot S(s_{i}|\vec{a}) \odot \phi_{0}(\vec{a}) \right ]_{j},
# \end{aligned} $$
# where $\Delta a_{j}$ denotes the bin width corresponding to the bin centered at $a_{j}$ used to approximate $S(s_{i}|a_{j})$. In the final equality, functions are vectorized and the operation $\odot$ denotes element-wise multiplication.
#
# **NOTE:** From here on out, whenever we convert an integral $\int ds$ to a sum $\sum_{j} ds_{j}$, we always use the same binning scheme.
#
# ## Calculating the Probability of Detecting and Selecting a Binary
# **Notation:**
# * $i$ corresponds to an observed binary, $j$ corresponds to an index in separation/semimajor axis that is summed over.
# * f_{\Delta G}(s/d) \equiv \Theta(s/d - \theta_{\Delta G}) (i.e., redefining the selection function $f_{\Delta G}$ in the paper)
#
# We set out to calculate one piece of the likelihood function:
# $$
# \begin{align}
#     p_b(s | d, \Delta G ; \lambda, f_{p}, \vec{\zeta}) = \frac{\phi(s |\lambda, f_{p}, \vec{\zeta}) \ \Theta(s/d - \theta_{\Delta G})}{\int ds' \ \phi(s'|\lambda, f_{p}, \vec{\zeta})  \ \Theta(s'/d - \theta_{\Delta G})},
# \end{align}
# $$
# In the total log-likelihood, you can check that the $\Theta$-function acts as a constant that does not affect our constraints, so we neglect it.
#
# We calculate this quantity for all binaries in our dataset in the form of a vector, $\vec{p_{b}}$. I.e., denote the numerator corresponding to all binaries as $\vec{\phi}$ and the denominator as $\vec{D}$. Then, to obtain the probabilities of being a binary for all binaries, we have
# $$ \vec{p_{b}} = \vec{\phi} \oslash \vec{\mathcal{D}} $$
# To calculate $\vec{\phi}$, we compute the expression for the evolved separation distribution above for all binaries. To calculate $\vec{\mathcal{D}}$, we must compute the integral in the numerator for all binaries.
#
# The manipulations in matrix form are as follows:
# 1. Load and compute $\vec{\Phi} = \Delta \vec{s} \odot \vec{\phi}$ where $\vec{\phi}$ evaluated at bin centers
# 2. Load $f_{ij} \equiv f_{\Delta G_{i}}(s_{j} / d_{i})$ and compute
# $$ \mathcal{D}_{i} = \sum_{j} \Delta s_{j} \odot \phi_{j} \odot f_{ij} = (\overleftrightarrow{f} \cdot \vec{\Phi})_{i}. $$
# 3. Load $\phi_{i}$, evaluated using the separations for all binaries in the catalog. $\phi$ here is collapsed to our histogram by using the *scipy.stats.rv_histogram* function
# 4. Compute
# $$ \vec{p_{b}} = \vec{\phi} \oslash \vec{\mathcal{D}} $$
#
# ## Calculating the Probability of Detecting and Selecting a Chance-Alignment
# The exact same as for a binary. Replace $p_{b} \rightarrow p_{c}$ and $\phi \rightarrow \phi_{c}$.
#
# ## Calculating the Log-Likelihood
# We have vectors $\vec{p_{b}}$ and $\vec{p_c}$. We calculate the total probability using the vectorial equation:
# $$
# \begin{align} \label{eq:probability_final}
#      \vec{p} = (\vec{1} - \vec{\mathcal{R})} \odot \vec{p_b} +  \vec{\mathcal{R}} \odot \vec{p_{c}}.
# \end{align}
# $$
# Finally, we have the log-likelihood is:
# $$
#     \log \mathcal{L} = \sum_{i} \log(\vec{p}_{i}).
# $$
# Note, our constraints will not depend on the overall normalization of the log-likelihood.

# %% [markdown]
# # Defining the Selection Function

# %% [markdown]
# ## Pre-Load $f_{ij}$ Matrix
# Want to pre-load $f_{ij}$. To do this efficiently, we will evaluate $f$ element-wise on an array of values.
# $$ f_{ij} = f_{\Delta G_{i}}(s_{j} / d_{i}) = [f(\overleftrightarrow{\theta} / \vec{\theta_{0}})]_{ij}, $$
# where the division of angles denotes element-wise division between the column vectors in $\overleftrightarrow{\theta}$ and the column vector $\vec{\theta_{0}}$. This is the desired operation for the argument since the selection function's critical angle $\theta_{0}$ is independent of the separations of the binaries.
#
# Want to compute this as a function acting on an array. So require
# $$ \overleftrightarrow{\theta}/\vec{\theta_{0}} \equiv \overleftrightarrow{\Theta}. $$
# To perform the desired operation using the built-in *numpy* functions, need to write $\vec{\theta_{0}}$ in such a way that element-wise division of two matrices gives the desired operation. Let $\mathbb{1}_{ij} =1$ have the same shape as $\theta_{ij}$ (non-square). Then, we have
# $$ \overleftrightarrow{\theta}/\vec{\theta_{0}} = \overleftrightarrow{\theta}/(\mathbb{1} \times \vec{\theta_{0}}) $$
#
# However, numpy loads $\theta_{0,i}$ as a row vector $\theta_{0,i}^{T}$. So we must write the effective $\theta_{0}$ matrix as
# $$ \mathbb{1} \times \vec{\theta_{0}} = (\mathbb{1}^{T} \times \vec{\theta_{0}}^{T})^{T}, $$
# where the products here are element-wise.

# %%
## Preload selection function matrix

from scipy.interpolate import interp1d

def selection_fct(theta,theta0):
    if theta < theta0:
        return 0
    else:
        return 1
selection_fct_vec = np.vectorize(selection_fct)

delta_G_mid = [0.5,1.5,2.5,3.5,5,7,9.5]
theta_cut_vals = [3.06481262,  3.26382633,  3.94047254,  4.61711977,  6.24903233,  9.55266057, 11.98062847]
theta_cut_ = interp1d(delta_G_mid, theta_cut_vals, kind = 'linear', fill_value = 'extrapolate', assume_sorted = True)

catalog_theta0_vec = theta_cut_(catalog_delta_G_vec)
catalog_data = np.array(np.vstack((catalog_sep_vec, catalog_dist_vec, catalog_delta_G_vec, catalog_R_chance_align_vec, catalog_theta0_vec)))

theta_mat = np.outer( 1/catalog_data[1,:] , mid_data * AU_pc)   # \theta_ij = s_j / d_i
theta0_T = catalog_data[-1,:]    # \theta_0_i
theta0_mat = (np.ones(np.shape(theta_mat)).T * theta0_T).T   # (1 \times \theta_ij)
catalog_f_mat = selection_fct_vec(theta_mat,theta0_mat)    # f(\theta_mat / \theta_0_mat)

# %%
fig = plt.figure(figsize=(4, 4), dpi= 120)
ax = fig.add_subplot(111)

ax.scatter(catalog_sep_vec, selection_fct_vec(catalog_sep_vec * AU_pc / catalog_dist_vec, catalog_theta0_vec), s = 0.5, c = 'b', label = 'Data')
    
ax.set_xlabel('$s$ (pc)')
ax.set_ylabel('$f_{\\Delta G}$')
ax.set_xscale('log')
ax.set_xlim([10**-4,1])
ax.set_ylim([0,1.05])
# Out:
# (0.0, 1.05)

# %%
fig = plt.figure(figsize=(4, 4), dpi= 120)
ax = fig.add_subplot(111)

for n in range(70):
    ax.scatter(theta_mat[n,:], catalog_f_mat[n,:], s = 0.5, label = 'Data')
    
ax.set_xlabel('$s$ (pc)')
ax.set_ylabel('$f_{\\Delta G}$')
ax.set_xscale('log')

# %% [markdown]
# ## Define Log-Likelihood
# 1. Initial Semimajor Axis Distribution: $\phi_{0}(a|\lambda) \propto a^{-\lambda}$
#     - Fix normalization factor to 1
# 2. Evolved Separation Distribution: $\phi(s|\lambda, f_{p}, \vec{\zeta})$
#     - Use normalization factor of initial semimajor axis dist
# 3. Chance Alignment Distribution: $\phi_c (s|\lambda_c ) \propto s^{-\lambda_c } )$
#     - Fix normalization factor to 1
# 4. Constraints on model parameters: theta_is_within_bounds
# 5. Log Likelihood: $\log \mathcal{L}$ (using results from Sec.3)
#
# Free Model Parameters: $\lambda, \lambda_{c}, f_{p}$

# %% [markdown]
# ## Subtlety: Varying $f_{p}$
#
# To set our constraints, we must vary over the free parameters: $\lambda, \lambda_{c}, f_{p}$. Varying the first two is quick as we have formulas to do this. However, it is not simple for $f_{p}$ because varying it would change the scattering matrix. We can consider various $f_{p}$-values by running simulations over many values of $f_{p}$ and "interpolating" the scattering matrix over values in between the discrete values of $f_{p}$. We avoid this by identifying a rough correspondence between $f_{p}$ and $T$. For example, for simple scattering, where $d\mathcal{N}/dt = \rho \sigma v$, the expected number of encounters $N \propto \rho / T$. That is, if we know the number of scatters for some $\rho$ of perturbers acting on a target for a fixed time $T$, then we know the number of scatters for any smaller $(1-\varepsilon) \rho$ would be equal to the number of scatter in the situation where, instead, the density is $\rho$ and the evolution time is reduced to $(1-\varepsilon) T$.
#
# Not only would this require more simulations, but it require us to constantly have to load different scattering matrices every time we attempt to vary likelihood. This motivates a faster way to calculate the posterior for a different perturber fraction. It involves identifying that the time between encounters $\delta t$ depends on $f_{p}$. For instance, the equation for the evolution time $T = N \delta t$ can be rewritten as
# $$ T = \frac{N}{f_{p}} \left (  \frac{M_p}{\rho_{DM} \times \pi p_{max}^{2}} \times  \langle v_p^{-1} \rangle \right). $$
# Therefore, simulations lasting $10 \ \rm{Gyr}$ use a different number of timesteps depending on the specified perturber fraction.
#
# As pointed out in the *evolution.ipynb* notebook, our simulations save the scattering matrix over different timesteps up to the timestep $N$ roughly corresponding to evolution time $T$. If we originally simulate a system with perturber fraction $f_{max}$, we represent any $f_{p} < f_{max}$ simulation with a previous timestep using the above relation.
#
# This approach would be valid if the evolution of the binary is dependent only on the number of encounters and not the time elapsed between the encounters. This is not the case. Note that binaries have more time to travel along their orbit and hence change their separations between encounters if the timesteps are large. In this remapping approach to simulate $f_{p}$, smaller $f_{p}$ values would have times between encounters that are too small since they are using the $\delta t$ that corresponds to the larger perturber fraction. This means that some binaries don't evolve as much as they could. It is more likely that this would cause binaries to have smaller orbits than they should since those near the pericenter would be more likely to escape towards the apocenter if they have more time. Thus, we expect the remapping approach to slightly underestimate the impact of encounters as opposed to performing simulations for each perturber fraction. By running simulations for both cases, we identified that the most significant deviations between both approaches occur for simulations where the evolved binary distribution is only slightly affected by the impact of perturbers. When there is little to no effect or the strongest possible effect on the distribution, the approaches agree and hence won't affect our constraints significantly.
#
# ![image.png](attachment:image.png)
#
# Therefore, whenever we "vary" $f_{p}$ in the code. We do so by calculating the evolution time $T$ above and generate from it the timestep corresponding to 10 Gyr, $N_{f_{p}}$, which is less than $N$ and contained in our scattering matrix file.

# %%
# ========================================

# Inputs
p0_bounds = [[0,3],[-3,3],[-3,log_f]]
power_law_index = 1.73
power_law_index_ca = -1

N_data = np.size(catalog_data[0,:])

# --------------------------------------------------

# load initial separation distribution (neglect normalization)
def dn0da_fct(a,l):
    return a**-l 

# evolve separation distribution to T ~ 10 Gyr
def phi(free_params):
    power_index = free_params[0]
    log_f = free_params[-1]
    f = 10**(log_f)

    # evolve histogram to T ~ 10 Gyr (depends on f)
    delta_t_val_f = delta_t_(m,inv_v_avg,f,p_max)    # delta_t value
    N_f = int(T / delta_t_val_f)    # number of time steps
    timestep = N_f - 1

    dn0da = dn0da_fct(mid,power_index)
    delta_a = np.diff(bins)      # bin spacing vector
    dnda = []                       # evolved histogram counts
    for i in range(len(mid)): 
        a0 = results_list[i][0]
        p_i = np.array([results_list[j][1][1][0][i,timestep] for j in range(len(mid))])        # survival probability (scattering matrix S(s_i|\vec{a}))
        dnda = np.concatenate(([dnda, [np.sum(p_i * delta_a * dn0da)]]))
    return dnda / np.sum(np.diff(bins) * dnda) # notice we need to normalize since the rv_histogram.pdf is normalized

def phi_ca(free_params):
    power_index_ca = free_params[1]
    return dn0da_fct(mid, power_index_ca)

# see contamination_rate_fit local file for plot
#def contamination_probability_(s,parameter_vec):
#    polynomial_ = np.poly1d(parameter_vec)
#    polynomial_value = polynomial_(s)
#    return polynomial_value * np.heaviside(polynomial_value,0)

def theta_is_within_bounds(theta, theta_bounds):
    '''
    helper function for flat priors or restricted likelihoods. 
    theta: array of floats, e.g. [1, 2, 3]
    theta_bounds: array of constraints, e.g. [[0, None], [0, 3], [None, 5] 
    If there's a None in theta_bounds, the prior will be improper. 
    '''
    for i, param in enumerate(theta):
        this_min, this_max  = theta_bounds[i]
        
        if this_min is None:
            this_min = -np.inf
        if this_max is None:
            this_max = np.inf
        if not (this_min <= param < this_max):
            return False
    return True

# Contamination rate accounted for. Needed to restrict integration to data separations
# Otherwise, contamination probability would be greater than 1 and give an NAN log(denominator)
def log_likelihood(free_params, inputs):
    power_index = free_params[0]
    power_index_ca = free_params[1]
    log_f = free_params[-1]
    
    p0_bounds = inputs[-1]
    if theta_is_within_bounds(free_params, p0_bounds) == False:
        return -np.inf
    
    catalog_data = inputs[0]
    
    phi_vec = phi(free_params)
    phi_fct = rv_histogram([phi_vec,bins])
    
    numerator = phi_fct.pdf(catalog_data[0,:])
    Phi = np.diff(bins_data) * phi_vec[n_min:n_max] 
    denominator = np.dot(catalog_f_mat,Phi)
    
    prob = (1 - catalog_data[3,:]) * numerator / denominator
    
    phi_ca_vec = phi_ca(free_params)
    phi_ca_fct = rv_histogram([phi_ca_vec,bins])
    
    numerator_ca = phi_ca_fct.pdf(catalog_data[0,:])
    Phi_ca = np.diff(bins_data) * phi_ca_vec[n_min:n_max] 
    denominator_ca = np.dot(catalog_f_mat,Phi_ca)
    
    prob_ca = catalog_data[3,:] * numerator_ca / denominator_ca
    return np.sum(np.log(prob + prob_ca))

# %% [markdown]
# ## Example: Evolved Separation Distribution

# %%
from scipy.stats import rv_histogram

# evolve histogram for specified timestep
log_f = -1
f = 0.1 # halo fraction [setting max number of time steps]
delta_t_val_f = delta_t_(m,v0,f,p_max)    # delta_t value
N_f = int(T / delta_t_val_f)    # number of time steps
timestep = int( (N_f - 1) / 1 )

l = 1.65

free_params = [1.73,-1,0]
phi_hist = phi(free_params)
hist_dist = rv_histogram([phi_hist,bins])

fig = plt.figure(figsize=(4, 4), dpi= 120)
ax = fig.add_subplot(111)

#n_a0 = np.where(mid >= 0.095)[0][0]
#a0, results_a0 = results_list[n_a0]

alist = np.logspace(-5,0,1000)
ax.bar(mid[n_min:n_max],phi_hist[n_min:n_max],width=np.diff(bins[n_min:n_max+1]),alpha=0.5, label = 'Normalized Histogram', color = 'orange')
ax.scatter(alist,hist_dist.pdf(alist), label  = 'rv_histogram', s = 1, marker = '_', c = 'k')

ax.set_xlabel('a (pc)')
ax.set_ylabel('Number of Binaries')
if bin_scale == 'log': ax.set_xscale('log')
if bin_scale == 'lin': ax.set_xscale('linear')
ax.set_yscale('log')
#ax.set_xlim([0.000245218616272841,1])
#ax.set_ylim([0.001,np.max(n) * 10])
ax.set_title('Evolved Binaries')

ax.set_xlim([10**-5, 10**2])

textstr1 = '\n'.join((
    r'Input Parameters:',
    r' ',
    r'$\log M_p /M_{\odot}=%.2f$' % (np.log10(m), ),
    r'$v_{0}/(km/s)=%.2f$' % (v0, ),
    r'$f_ p =%.2f$' % (f, ) 
))

textstr2 = '\n'.join((
    r'Output Parameters:',
    r' ',
    r'$N=%.2f$' % (N_f, ),
    r'$K=%.2f$' % (K, ),
    r'$\log N_{enc}=%.2f$' % (np.log10(N_enc), ),
    r'$p_{max}/pc=%.2f$' %(R, ),
#    r'$Binary \ Loss \ Fraction=%.2f$' % (len(np.where(a_final_array>1)[0]) / K, )
))

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(1.2, 1.1, textstr1, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax.text(1.2, 0.6, textstr2, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax.legend()

# %% [markdown]
# ## Example: Likelihood Function vs $f_{p}$

# %%
inputs = [catalog_data,p0_bounds]

p0_bounds = [[0,3],[-3,3],[-3,0.2]]
power_law_index = 1.5
power_law_index_ca = -1

log_fp_list = np.linspace(p0_bounds[-1][0],0.2,100)

log_likelihood_vec = []
for log_fp in log_fp_list:
    free_params_0 = [power_law_index, power_law_index_ca, log_fp]
    log_likelihood_val = log_likelihood(free_params_0, inputs)
    log_likelihood_vec = np.concatenate((log_likelihood_vec, [log_likelihood_val]))

fig = plt.figure(figsize=(3,3), dpi= 120)
ax = fig.add_subplot(111)
    
ax.plot(log_fp_list,log_likelihood_vec)
    
ax.set_xscale('linear')
ax.set_yscale('linear')

ax.set_title('$\\log(M_p /M_{\\odot}) = $' + str_log_m)
ax.set_xlabel('$\\log(f_{p})$')
ax.set_ylabel('$\\log \\mathcal{L}$')
# Out:
# Text(0, 0.5, '$\\log \\mathcal{L}$')

# %% [markdown]
# ## Log-Likelihood Minimization
# Though it isn't necessary, we can minimize the log-likelihood to get an idea of where we should sample the posterior distribution for the model parameters.

# %%
free_params_0 = np.array([1.618096 ,-1, -1])  # obtained using no perturber broken power law fit (and eyeballing)
p0_bounds = [[0,3],[-3,1],[-3,0.2]]

ti = time.time()

res = minimize(lambda free_params, inputs: -log_likelihood(free_params, inputs),free_params_0,args = [catalog_data,p0_bounds],
                        method = 'Nelder-Mead', 
                        options={'maxiter':2000,'maxfev':2000,'adaptive':True,'xatol':0.0000001,'fatol':0.0000001})

calc_time_minimization = time.time() - ti

print('Finished Minimization Procedure: ' + str.format('{0:.2f}',calc_time_minimization/60) +  ' min')
print(res)
# Out:
# Finished Minimization Procedure: 0.16 min
#  final_simplex: (array([[ 1.62065041,  0.73349719, -0.7105143 ],
#        [ 1.62065039,  0.73349717, -0.7105143 ],
#        [ 1.62065039,  0.73349719, -0.7105143 ],
#        [ 1.6206504 ,  0.73349728, -0.7105143 ]]), array([-27752.38874702, -27752.38874702, -27752.38874702, -27752.38874702]))
#            fun: -27752.388747021632
#        message: 'Optimization terminated successfully.'
#           nfev: 432
#            nit: 222
#         status: 0
#        success: True
#              x: array([ 1.62065041,  0.73349719, -0.7105143 ])

# %% [markdown]
# # Inferring Limits on Parameters
# A majority of this code is a modified version of El-Badry's **sep_dist** github repository (https://github.com/kareemelbadry/sep_dist)
#
# ## Loading the Log-Prior and Log-Posterior
# Here, we essentially apply Bayes' Theorem. Define:
#
# 1. Log Flat Priors on Model Parameters
#     - We assume flat priors on the model parameters specified by p0_bounds
# 2. Log Posterior
#     - We use Bayes' Theorem with our log-likelihood and log-flat posteriors

# %%
# ========================================
# Initializing the log posterior

def log_flat_prior(theta, theta_bounds):
    '''
    theta: array of parameters, e.g. [1, 2, 3]
    theta_bounds: array of the same length, but with a list of length
        two (lower and upper bounds) at each element. e.g.
        [[0, 2], [1, 3], [2, 6]]
    '''
    if theta_is_within_bounds(theta, theta_bounds):
        return 0
    else: 
        return -np.inf

def log_posterior(free_params, inputs):
    p0_bounds = inputs[-1]
    lnprior = log_flat_prior(theta = free_params, theta_bounds = p0_bounds)
    if np.isfinite(lnprior):
        lnlikelihood = log_likelihood(free_params,inputs)
    else:
        lnlikelihood = 0 
    return lnprior + lnlikelihood

# %% [markdown]
# # Emcee Sampling
#
# Having defined the posterior function, we can now use the *emcee* package to describe the posterior distriution and infer limits on the model parameters. Performance is determined by the parameters $\{n_{walkers}, burn, n_{steps}\}$---the number of walkers, the number of steps used to burn in the positions of the walkers, and the number of steps that the walkers take to sample the posterior distributon. Prior to running, we set the initial positions of the walker around the maximum of the posterior (however, it isn't necessary as we are burning in the walkers). Run the code below to produce the corner plot giving parameter limits.

# %%
# ========================================
# Inputs for emcee

nwalkers = int(32)
str_nwalkers = str(nwalkers)

burn = int(50)
str_burn = str(burn)

n_steps = int(100)
str_n_steps = str(n_steps)

# -----------------------------------------
# Running the emcee code

# Set initial walker positions
def get_good_p0_ball(p0, theta_bounds, nwalkers, r = 0.01):
    '''
    Utility function for initializing MCMC walkers. Returns walkers clustered around a 
    point p0 in parameter space, all of which fall within theta_bounds. 
    
    p0: point in parameter space that we think might have a high probability. e.g. [1, 2, 3]
    theta_bounds: the range of parameter space within which we'll allow the walkers to explore;
        we have flat priors within this region. E.g. [[0, 2], [1, 3], [2, 4]]
    nwalkers: int; number of walkers to initialize
    r: float. Decreasing this makes the walkers more and more clustered around p0
    '''
    num_good_p0 = 0

    ball_of_p0 = []
    while num_good_p0 < nwalkers:
        #suggested_p0 = p0 + np.array([r*j*np.random.randn() for j in p0])
        suggested_lambda = p0[0] + r*p0[0]*np.random.randn()
        suggested_lambda_ca = p0[1] + r*p0[1]*np.random.randn()
        suggested_log_fp = p0[-1] + r*np.random.randn()
        suggested_p0 = np.array([suggested_lambda,suggested_lambda_ca,suggested_log_fp])
        suggested_p0_prob = log_flat_prior(suggested_p0, theta_bounds = theta_bounds)
        if np.isfinite(suggested_p0_prob):
            ball_of_p0.append(suggested_p0)
            num_good_p0 += 1
    return ball_of_p0

file_name = ( 'emcee_splaw_' + str_log_m + '_' + str_log_K + '_'
             + bin_scale + '_' + str_log_alow + '_' + str_log_ahigh + '_' + str_step_size + '_'
             + str_log_alow_offset + '_' + str_log_ahigh_offset + '_'
             + str_nwalkers + '_' + str_burn + '_' + str_n_steps )

# %%
inputs = [catalog_data,p0_bounds]
p0 = res.x
ndim = len(p0)
theta_bounds = inputs[-1]
p0_ball = get_good_p0_ball(p0 = p0, theta_bounds = theta_bounds, nwalkers = nwalkers, r = 0.01)

calc_time_emcee = [calc_time_minimization]

print('initialized walkers... burning in...')
sampler = emcee.EnsembleSampler(nwalkers = nwalkers, dim = ndim, lnpostfn = log_posterior, args = [inputs], threads = 16)
pos, prob, state = sampler.run_mcmc(p0_ball, burn)
sampler.reset()
print('completed burn in ...')

calc_time_emcee = np.concatenate((calc_time_emcee, [time.time() - ti]))

for i, result in enumerate(sampler.sample(pos, iterations = n_steps)):
    if (i+1) % 50 == 0:    
        print("{0:5.1%}".format(float(i) / n_steps))
        calc_time_emcee = np.concatenate((calc_time_emcee, [time.time() - ti]))
        
# ========================================

# Saving all the results (ignore dimension_master and separation distributions)

emcee_res = [sampler.flatchain, sampler.chain, sampler.lnprobability]
calc_time_emcee = np.concatenate((calc_time_emcee, [time.time() - ti]))
result = [emcee_res,catalog_data,res,calc_time_emcee]
np.save(file_name,result)
# Out:
# initialized walkers... burning in...
# completed burn in ...
# 49.0%
# 99.0%
# /home/edr/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ## Plot the Sampled Posterior with Corner

# %%
import corner

# plot the constraints
label_names = [r'$\lambda$', r'$\lambda_{ca}$', r'$\log_{10} \ f_{p}$'] 
_ = corner.corner(sampler.flatchain, labels = label_names, quantiles=[0.05, 0.5, 0.95], 
                  levels = (1 - np.exp(-0.5), 1 - np.exp(-2), 1 - np.exp(-9 / 2.)),
    show_titles=True, title_kwargs={"fontsize": 12}, bins = 20)

# %%
flatchain = sampler.flatchain

# plot distributions with free parameters sampled from posterior
fig = plt.figure(figsize=(3,3), dpi= 120)
ax = fig.add_subplot(111)

# obtain samples from the emcee flat chain and produce plots of separation distributions for each
inds = np.random.randint(len(flatchain), size=100)
for ind in inds:
    sample = flatchain[ind]
    free_params = np.array([sample[0] , sample[1] , sample[2]])
    dn0da = dn0da_fct(mid,sample[0])[n_min:n_max]
    phi0 = dn0da / np.sum(np.diff(bins_data) * dn0da)
    dnda = phi(free_params)[n_min:n_max]
    phi_vec = dnda / np.sum(np.diff(bins_data) * dnda)
    phi_fct = rv_histogram([phi_vec,bins_data])
    phi_fct.rvs(N_data)
    
    #data_theta = np.divide(data_sep, data_dist)
    #data_f = selection_fct(data_theta,theta0,beta)
    
    ax.plot(mid_data, phi_vec, lw = 0.5, alpha=0.1, c='orange')
    ax.plot(mid_data, phi0, lw = 0.5, alpha=0.1, c='green')

# produce density histogram of the data
counts, bins_cat = np.histogram(catalog_data[0,:],bins=bins_data, density = True)
binscenters = np.array([0.5 * (bins_data[i] + bins_data[i+1]) for i in range(len(bins_data)-1)])
ax.scatter(binscenters,counts, c='b', marker='.', label = 'Catalog')

ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()

ax.set_title('$\\log(M_{p}/M_{\\odot}) = $' + str_log_m)
ax.set_xlabel('$a$ (pc)')
ax.set_ylabel('Separation Distribution')
ax.set_xlim([mid[n_min],mid[n_max]])
#ax.set_ylim([np.min(phi_norm_to_cat(free_params)),
#             np.max(phi_norm_to_cat(free_params))])
# Out:
# (0.0005501236987934667, 1.0482390980716034)
